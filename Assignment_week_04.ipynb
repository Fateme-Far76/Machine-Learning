# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the file
with open('housing-data.txt', 'r') as file:
    content = file.readlines()

# Extract column names from the first row
column_names = content[0].strip().split(',')

# Create a list of dictionaries for each row (excluding the first row)
data = []
for line in content[1:]:

    # Split the line into columns
    columns = line.strip().split(',')

    # Create a dictionary for the row
    row = {}
    for i, col_name in enumerate(column_names): 

        # Convert column value to numeric type
        row[col_name] = pd.to_numeric(columns[i])
        
    # Add the row to the data list
    data.append(row)

# Create the DataFrame
df = pd.DataFrame(data)
df
# Out:
#       size       price
# 0     30.0   75.760161
# 1     31.0   81.662679
# 2     32.0   60.944950
# 3     33.0   67.890597
# 4     34.0   87.957014
# ..     ...         ...
# 195  225.0  274.688859
# 196  226.0  264.306241
# 197  227.0  280.971109
# 198  228.0  255.968253
# 199  229.0  273.728558
#
# [200 rows x 2 columns]

# %%
plt.scatter(df['size'], df['price'], s=10, c='b', marker='o', alpha=0.5)
plt.xlabel('Size')
plt.ylabel('Price')
plt.title('Price vs Size of houses')
plt.show()

# %%
def compute_cost(X, y, theta):
    m = X.shape[0]  
    h = np.dot(X, theta)
    cost = np.sum((h - y) ** 2) / (2 * m)
    return cost

# %%
def gradient_descent(X, y, theta, alpha, num_iters):
    m = X.shape[0] 
    ones_column = np.ones((m, 1))
    X = np.concatenate((ones_column, X), axis=1)
    
    costs = []  # List to store the costs
    
    for _ in range(num_iters):
        h = np.dot(X, theta)
        error = h - y
        gradient = np.dot(X.T, error) / m
        theta = theta - alpha * gradient
        
        # Calculate the cost and append it to the list
        cost = compute_cost(X, y, theta)
        costs.append(cost)
    
    return theta, costs

# %% [markdown]
# ### Values of $J(\theta)$

# %% [markdown]
# The plot of J(θ) values should ideally show a downward trend, steadily decreasing and eventually flattening out when the algorithm has converged to the optimal theta values.

# %%
# Initialize some parameters 
X = df['size'].values.reshape(-1, 1)  
y = df['price'].values.reshape(-1, 1)  
 
theta = np.zeros((2, 1))
alpha = 0.1
num_iters = 1000

# Run gradient descent
updated_theta, cost_history = gradient_descent(X, y, theta, alpha, num_iters)

# Plot the cost history
plt.plot(range(num_iters), cost_history)
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.title('Cost History')
plt.show()
# Out:
# C:\Users\Ashil_rayan\AppData\Local\Temp\ipykernel_1980\1325420137.py:4: RuntimeWarning: overflow encountered in square
#   cost = np.sum((h - y) ** 2) / (2 * m)
# c:\Users\Ashil_rayan\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Ashil_rayan\AppData\Local\Temp\ipykernel_1980\1659116736.py:12: RuntimeWarning: invalid value encountered in subtract
#   theta = theta - alpha * gradient

# %% [markdown]
# But we're not seeing this.
# The cost is increasing.
# it is suggested the learning rate is too high and the gradient descent algorithm is overshooting the minimum.

# %% [markdown]
# The assignment has been done with collaboration of Samaneh Shahpouri
